# %%
import numpy as np

# %%
a = np.array([[7,2],
             [-7,5]])
b = np.array([-5,12])

# %%
invA = np.linalg.inv(a)
x = invA*b
x_ans = np.dot(invA,b)
print(invA)
print(x)
print(x_ans)
# Out:
# [[ 0.10204082 -0.04081633]
#  [ 0.14285714  0.14285714]]
# [[-0.51020408 -0.48979592]
#  [-0.71428571  1.71428571]]
# [-1.  1.]
