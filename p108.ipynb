# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([3,4])

# %%
# Figure 객체 만들기
fig = plt.figure()

# %%
# 1x1개의 서브플롯을 추가하고 첫번째 서브플롯사용
ax = fig.add_subplot(1,1,1)

# %%
ax.scatter(a[0],a[1],s=30)

# %%
ax.text(a[0]+0.2,a[1]+0.2,'a',size = 15)
# Out:
# Text(3.2, 4.2, 'a')

# %%
fig

# %%
ax.set_xticks(range(-5,6))
ax.set_yticks(range(-5,6))
# Out:
# [<matplotlib.axis.YTick at 0x1df4d7f6e88>,
#  <matplotlib.axis.YTick at 0x1df4d7f60c8>,
#  <matplotlib.axis.YTick at 0x1df5089a188>,
#  <matplotlib.axis.YTick at 0x1df50dc8b08>,
#  <matplotlib.axis.YTick at 0x1df50dcd348>,
#  <matplotlib.axis.YTick at 0x1df50dcdc48>,
#  <matplotlib.axis.YTick at 0x1df50dd1848>,
#  <matplotlib.axis.YTick at 0x1df50dd1188>,
#  <matplotlib.axis.YTick at 0x1df50dd4608>,
#  <matplotlib.axis.YTick at 0x1df50dd7048>,
#  <matplotlib.axis.YTick at 0x1df50dd7b88>]

# %%
ax.grid()
ax.set_axisbelow(True)

# %%
fig

# %%
# x축과 y축 눈금의 비율을 1:1로 합니다
# 창의 크기를 변경해도 비율이 유지됩니다.
ax.set_aspect('equal',adjustable = 'box')

# %%
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_position('zero')

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# %%
# pycharm같은 IDE에서 활용하기
#plt.show()

# %%
fig
